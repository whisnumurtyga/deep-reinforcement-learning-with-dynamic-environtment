# %%
import pandas as pd

# %%
df = pd.read_csv('./data_append.csv')
pd.set_option('display.max_rows', None)  # Menampilkan semua baris

df.head(100)
# Out:
#     generation  car_id start_position      end_position  is_finish  \
# 0            1       5     1656 - 665  1640.06 - 669.27      False
# 1            1       8     1656 - 665  1640.06 - 669.27      False
# 2            1      11     1656 - 665  1640.06 - 669.27      False
# 3            1      14     1656 - 665  1640.06 - 669.27      False
# 4            1      16     1656 - 665  1640.06 - 669.27      False
# 5            1      19     1656 - 665  1640.06 - 669.27      False
# 6            1      20     1656 - 665  1640.06 - 669.27      False
# 7            1      22     1656 - 665  1640.06 - 669.27      False
# 8            1      25     1656 - 665  1640.06 - 669.27      False
# 9            1      29     1656 - 665  1640.06 - 669.27      False
# 10           1       4     1656 - 665  1623.56 - 669.27      False
# 11           1       5     1656 - 665  1640.06 - 669.27      False
# 12           1       8     1656 - 665  1640.06 - 669.27      False
# ...

# %%
df['is_finish'].value_counts()
# Out:
# False    20799
# Name: is_finish, dtype: int64
